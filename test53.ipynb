# %% [markdown]
# # inputs : two variables x and y

# %% [markdown]
# # output : change the values of x and y without any other variable

# %%
x = int(input())
y = int(input())

# %%
x = x + y
y = x - y
x = x - y

# %%
print(x)
print(y)
