# %% [markdown]
# # inputs : integer a & string b

# %% [markdown]
# # outputs : id of them

# %%
a = int(input('insert an integer please : '))
b = input('insert a string please : ')

# %%
print('ID of your integer is : ',id(a))
print('Id of you string is : ',id(b))
