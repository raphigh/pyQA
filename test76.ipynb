# %%
from IPython.display import Image
Image(filename='seq.jpg')

# %%
x = int(input())
# Out:
# 5

# %%
sum = 0
temp = 0
for i in range(1,11):
    a = (-1)**(i+1)
    temp += i*(x ** i)
    sum += a * (1/temp)

# %%
print(sum)
# Out:
# 0.18384874697896247
