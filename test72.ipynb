# %% [markdown]
# # input : a string

# %% [markdown]
# # output : print the string with  a space between each letters

# %%
s = input()
# Out:
# hello

# %%
for i in s:
    print(i,end = ' ')
# Out:
# h e l l o
