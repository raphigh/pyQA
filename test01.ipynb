# %% [markdown]
# # input:base & height of parallelogram

# %% [markdown]
# # output:area

# %%
base = float(input('insert the base of parallelogram please : '))
height = float(input('insert the height of parallelogram please : '))

# %%
area = base * height

# %%
print(area)
