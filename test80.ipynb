# %% [markdown]
# # inputs:یک رشته

# %% [markdown]
# # output:تعداد حروف صداد دار

# %%
a = input()
# Out:
# happy new year

# %%
b = ['a','e','i','o','u']

# %%
counter = 0
for i in a:
    if i in b:
        counter += 1
    else:
        continue

# %%
print(counter)
# Out:
# 4
