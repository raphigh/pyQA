# %% [markdown]
# # input:radius of sphere

# %% [markdown]
# # outputs:volume & area of sphere

# %%
from math import pi

# %%
radius = float(input('radius of the sphere : '))

# %%
volume = (4/3) * pi * (r ** 3)
surarea = 4 * pi * (r ** 2)

# %%
print('volume is : ',volume)
print('surarea is : ',surarea)
