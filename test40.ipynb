# %% [markdown]
# # inputs : two integers m and n

# %% [markdown]
# # outputs : a = m^2 - n^2,b = 2 * m * n ,c = m^2 + n^2

# %%
m = int(input('insert first number : '))
n = int(input('insert second number : '))

# %%
a = m**2 - n**2
b = 2*m*n
c = m**2 + n**2

# %%
a

# %%
b

# %%
c
