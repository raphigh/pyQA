# %% [markdown]
# # input:تعدادی عدد

# %% [markdown]
# # output : چاپ اعدادی که بر 9 بخشپذیرند

# %%
while True:
    a = input()
    if a.isnumeric() == False:
        break
    else:
        if int(a)%9 == 0 :
            print(a)
        else:
            continue
# Out:
# 2
# 3
# 9
# 9
# 18
# 18
