# %% [markdown]
# # input: a number

# %% [markdown]
# # output:identify the number is Symmetrical or not

# %%
a = input()
# Out:
# 121

# %%
b = list(a)
b.reverse()

# %%
if list(a) == b :
    print('yes')
else:
    print('no')
# Out:
# yes
