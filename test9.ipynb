# %% [markdown]
# # input : your age

# %% [markdown]
# # output: the seconds that you've lived

# %%
age = int(input('insert your age please : '))

# %%
ss = age * (3.156 * (10 ** 7))

# %%
print(ss)
