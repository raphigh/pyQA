# %% [markdown]
# # input : salary of an employee

# %% [markdown]
# # output : final salary

# %%
salary = float(input('salary : '))

# %%
insurance = salary * (7/100)
task = salary * (10 / 100)
final_salary = salary - insurance - task

# %%
print(final_salary)
