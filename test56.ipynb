# %% [markdown]
# # inputs : salary per hour & work time

# %% [markdown]
# # output : salary

# %% [markdown]
# # note : tax = 10%

# %%
h = float(input('salary per hour : '))
t = int('work time : ')

# %%
ans = h * t *(9/10)

# %%
print(ans)
