# %% [markdown]
# # inputs : first velocity & last velocity & time

# %% [markdown]
# # output : acceleration

# %%
v0 = float(input('first velocity : '))
v1 = float(input('last velocity : '))
t = float(input('time : '))

# %%
a = (v1 - v0)/t

# %%
print(a)
