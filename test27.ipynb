# %% [markdown]
# # inputs : two integers

# %% [markdown]
# # outputs : int1 * + - / % int2

# %%
a = int(input('integer 1 : '))
b = int(input('integer 2 : '))

# %%
a * b

# %%
a + b

# %%
a - b

# %%
a / b

# %%
a % b
