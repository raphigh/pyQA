# %% [markdown]
# # inputs : small base & big base & height of a trapezius

# %% [markdown]
# # output : area

# %%
sb = float(input())
bb = float(input())
h = float(input())

# %%
area = ((sb + bb) * h)/2

# %%
print(area)
