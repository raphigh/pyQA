# %% [markdown]
# # input : integer a

# %% [markdown]
# # outputs : square & cube of a

# %%
a = int(input('insert an integer named a : '))

# %%
print('the square of %d is : '%(a),a ** 2)
print('the cube of %d is : '%(a),a ** 3)
