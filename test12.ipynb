# %% [markdown]
# # input : the number of employees

# %% [markdown]
# # output : Additional cost if 13.5 percent is added to employee salaries

# %% [markdown]
# note : the base salary is 75000

# %%
n = int(input('the number of employees is : '))

# %%
base_cost = n * 75000
extra = base_cost * (13.5/100)

# %%
print(extra)
