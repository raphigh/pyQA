# %% [markdown]
# # inputs : electrical resistance & electricity flow

# %% [markdown]
# # output : Voltage

# %%
r = float(input('electrical resistance : '))
i = float(input('electricity flow : '))

# %%
v = r * i

# %%
print('voltage is : ',v)
