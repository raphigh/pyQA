# %% [markdown]
# # inputs : a string & number of repetition

# %% [markdown]
# # output: rep times string

# %%
s = input('insert a string please : ')
rep = int(input('insert the number of repetitions please : '))

# %%
ans = s * rep

# %%
print(ans)
