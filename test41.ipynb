# %% [markdown]
# # inputs : two integer named a and b

# %% [markdown]
# # outputs : a + b , a - b , a * b , a / b , a^2 + b^2 , a^2 - b^2

# %%
a = int(input('insert first number plaese : '))
b = int(input('insert second number please : '))

# %%
print(a + b,a-b,a * b,a/b,a**2 + b**2,a**2 - b**2)
