# %% [markdown]
# # input : parallel electrical resistances R1 , R2 , R3

# %% [markdown]
# # output : sum of them

# %%
r1 = float(input('reisistance r1 : '))
r2 = float(input('reisistance r2 : '))
r3 = float(input('resistance r3 : '))

# %%
ans = 1/r1 + 1/r2 + 1/r3

# %%
print(ans)
