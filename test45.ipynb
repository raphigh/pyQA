# %% [markdown]
# # inputs : count & price of a thing

# %% [markdown]
# # output : sell price

# %%
count = int(input('count of this thing : '))
price = float(input('price of this thing : '))

# %%
sell = count * price

# %%
print(sell)
