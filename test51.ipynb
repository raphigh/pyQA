# %% [markdown]
# # inputs : three integers(x,y,z)

# %% [markdown]
# # output : x^3 + 2x^2 + y - 5

# %%
x = int(input())
y = int(input())
z = int(input())

# %%
print(x ** 3 + 2 * (x ** 2) + y - 5)
