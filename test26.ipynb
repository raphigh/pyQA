# %% [markdown]
# # inputs : Gasoline consumption(km/lit) & Buck capacity(lit)

# %% [markdown]
# # output : the distance that the car with full buck can go

# %%
cons = float(input('gasoline consumption : '))
cap = float(input('buck capacity : '))

# %%
distance = cons * cap

# %%
print(distance)
