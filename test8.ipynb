# %% [markdown]
# # input : water volume(lit)

# %% [markdown]
# # output : number of molecules in it

# %%
v = float(input('volume(lit) ? '))

# %%
mass = v * 950
MoleculesNumber = mass / (3 * (10 ** (-23)))

# %%
print(MoleculeNumber)
