# %% [markdown]
# # inputs : two real numbers

# %% [markdown]
# # output : complex number that its real part is first number and its img part is the second number

# %%
real = float(input('real part : '))
img = float(input('img part  : '))

# %%
com = complex(real,img)

# %%
print(com)
