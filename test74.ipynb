# %% [markdown]
# # inputs : three numbers

# %% [markdown]
# # output : sort them

# %%
l = []

# %%
for i in range(3):
    n = float(input())
    l.append(n)
l.sort()
# Out:
# 4
# 5
# 1.5

# %%
print(l)
# Out:
# [1.5, 4.0, 5.0]
