# %% [markdown]
# # input : integer named n

# %% [markdown]
# # output : n + nn + nnn

# %% [markdown]
# example :

# %% [markdown]
#     input : 3

# %% [markdown]
# output : 3 + 33 + 333 = 369

# %%
n = int(input('insert an integer : '))

# %%
n1 = int('%s'%(n))
n2 = int('%s%s'%(n,n))
n3 = int('%s%s%s'%(n,n,n))
ans = n1 + n2 + n3

# %%
print(ans)
