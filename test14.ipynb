# %% [markdown]
# # input : a number called x

# %% [markdown]
# # output : 31 * x - 17 * x + 5 without * operation

# %%
x = float(input('x'))

# %%
m = (x << 5) - x
n = (x<<4) + x
y = m + n + 5

# %%
print(y)
