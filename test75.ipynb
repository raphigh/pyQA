# %% [markdown]
# # inputs : (a,b) 's

# %% [markdown]
# # outputs : a * b without * operator

# %%
while True:
    l = []
    for i in range(2):
        n = int(input())
        l.append(n)
    a = l[1]
    for i in range(l[0] - 1):
        l[1] += a
    print(l[1])
# Out:
# 2
# 3
# 6
